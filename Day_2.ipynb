# %% [markdown]
# <a href="https://colab.research.google.com/github/muzamiliqbalganaie/machine-learning-model-/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import numpy as np
import random
a_rr = np.random.randint(40, 99, (15,6))
a_rr
# Out:
# array([[49, 53, 93, 72, 82, 58],
#        [82, 68, 68, 61, 64, 72],
#        [70, 84, 81, 50, 60, 95],
#        [70, 96, 69, 42, 85, 40],
#        [61, 87, 59, 86, 81, 60],
#        [71, 76, 50, 57, 68, 73],
#        [81, 76, 44, 81, 81, 70],
#        [87, 78, 49, 64, 87, 68],
#        [41, 55, 87, 60, 57, 90],
#        [76, 79, 55, 57, 56, 46],
#        [69, 53, 63, 59, 86, 41],
#        [67, 53, 76, 81, 82, 58],
#        [75, 98, 64, 73, 58, 52],
#        [58, 67, 91, 46, 69, 83],
#        [94, 89, 61, 41, 75, 47]])

# %%
a_rr.max()
# Out:
# 98

# %%
import seaborn as sns
sns.heatmap(a_rr,cmap="YlOrBr",annot=True)
# Out:
# <Axes: >

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
carsales_data=pd.read_csv("/content/car_sales_new.csv")

# %%
with pd.zipfile("location","r")as zip_file:
  pd.read_csv(zip_file.open("name of the file.csv"))

# %%
carsales_data.head(20)
# Out:
#               car       price       body  mileage  engV engType registration  \
# 0            Ford   15500.000  crossover       68   2.5     Gas          yes
# 1   Mercedes-Benz   20500.000      sedan      173   1.8     Gas          yes
# 2   Mercedes-Benz   35000.000      other      135   5.5  Petrol          yes
# 3   Mercedes-Benz   17800.000        van      162   1.8  Diesel          yes
# 4   Mercedes-Benz   33000.000      vagon       91   NaN   Other          yes
# 5          Nissan   16600.000  crossover       83   2.0  Petrol          yes
# 6           Honda    6500.000      sedan      199   2.0  Petrol          yes
# 7         Renault   10500.000      vagon      185   1.5  Diesel          yes
# 8   Mercedes-Benz   21500.000      sedan      146   1.8     Gas          yes
# 9   Mercedes-Benz   22700.000      sedan      125   2.2  Diesel          yes
# 10         Nissan   20447.154  crossover        0   1.2  Petrol          yes
# ...

# %%
carsales_data.tail(10)
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 9566            UAZ    850.0        van      255   NaN   Other          yes
# 9567           Jeep  13990.0  crossover      210   3.0  Diesel          yes
# 9568  Mercedes-Benz   5000.0      vagon      248   2.0     Gas          yes
# 9569     Volkswagen  18000.0  crossover      155   2.0  Diesel          yes
# 9570         Toyota  14474.0  crossover      115   2.0  Petrol          yes
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year           model  drive
# 9566  1981            3962    NaN
# 9567  2006  Grand Cherokee   full
# ...

# %%
carsales_data.sample(10)
# Out:
#                 car    price       body  mileage   engV engType registration  \
# 7523     Mitsubishi  10800.0  crossover      165   3.00     Gas          yes
# 6784      Chevrolet   6600.0      hatch       16   1.50     Gas          yes
# 2454  Mercedes-Benz  12900.0        van      185   2.20  Diesel          yes
# 7718     Volkswagen   7750.0        van      235   1.90  Diesel          yes
# 8483           Ford   3200.0      vagon      155   1.30     Gas          yes
# 6588     Volkswagen   9900.0      hatch      156   1.60  Petrol          yes
# 5782     Volkswagen   4300.0      hatch      217   1.60     Gas          yes
# 3425            VAZ   1420.0      sedan      450  99.99  Petrol          yes
# 8794          Skoda   7500.0      hatch       63   1.20  Petrol          yes
# 8301          Lexus  24555.0  crossover      152   4.70     Gas          yes
#
#       year                   model  drive
# 7523  2007            Pajero Sport   full
# ...

# %%
carsales_data.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
carsales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
carsales_data.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %%
total = carsales_data.isnull().sum().sort_values(ascending=False)
percent = (carsales_data.isnull().sum()/carsales_data.isnull().count()).sort_values(ascending=False)
missing_data=pd.concat([total,percent],axis=1,keys=['Total', 'Percent'])
print(missing_data)
# Out:
#               Total   Percent
# drive           511  0.053363
# engV            434  0.045322
# car               0  0.000000
# price             0  0.000000
# body              0  0.000000
# mileage           0  0.000000
# engType           0  0.000000
# registration      0  0.000000
# year              0  0.000000
# model             0  0.000000

# %%
carsales_data.describe(include='all')
# Out:
#                car          price   body      mileage         engV engType  \
# count         9576    9576.000000   9576  9576.000000  9142.000000    9576
# unique          87            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           936            NaN   3646          NaN          NaN    4379
# mean           NaN   15633.317316    NaN   138.862364     2.646344     NaN
# std            NaN   24106.523436    NaN    98.629754     5.927699     NaN
# min            NaN       0.000000    NaN     0.000000     0.100000     NaN
# 25%            NaN    4999.000000    NaN    70.000000     1.600000     NaN
# 50%            NaN    9200.000000    NaN   128.000000     2.000000     NaN
# 75%            NaN   16700.000000    NaN   194.000000     2.500000     NaN
# max            NaN  547800.000000    NaN   999.000000    99.990000     NaN
#
#        registration         year    model  drive
# ...

# %%
carsales_data['year'].value_counts()
# Out:
# 2008    1158
# 2007     930
# 2012     767
# 2011     701
# 2013     651
# 2006     564
# 2016     459
# 2005     413
# 2010     389
# 2014     368
# 2009     347
# 2004     338
# 2003     282
# 2015     249
# 2000     231
# 2002     219
# 2001     216
# 1999     160
# 1998     152
# 1996     125
# 1997     123
# 1995      85
# 1994      76
# 1991      70
# 1990      64
# 1992      62
# 1988      60
# 1993      53
# 1989      50
# 1986      45
# 1987      43
# 1985      28
# 1984      15
# 1982      10
# 1979      10
# 1980       9
# 1981       8
# 1983       7
# 1978       7
# 1977       6
# 1976       4
# 1969       3
# 1971       2
# 1963       2
# 1962       2
# 1974       2
# 1961       2
# 1968       1
# 1964       1
# 1972       1
# 1958       1
# 1970       1
# 1953       1
# 1973       1
# 1959       1
# 1975       1
# Name: year, dtype: int64

# %%
carsales_data['year'].value_counts().head(20).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# As the sales goes on high for the year of 2008

# %%
carsales_data['body'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# As the cars body sedan is high on volume

# %%
carsales_data.sample(100).plot.scatter(x='mileage',y='price')
sns.regplot(x='mileage',y='price',data=carsales_data)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %% [markdown]
# As we seen that mileage and price are indirectly related ,High price cars give low mileage

# %%
carsales_data.plot(kind='scatter',x='year',y='price',alpha=0.2,color='r')
plt.xlabel('year')
plt.ylabel('price')
plt.title("year - price Scatter Plot",color='blue')
plt.grid(True)
plt.show()

plt.savefig('yearVsPrice.png')

# %%
from IPython.display import Image,display
file_path='/content/yearVsPrice.png'
display(Image(filename=file_path))
